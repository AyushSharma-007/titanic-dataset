# %% [markdown]
# ### 18-06-2024  titanic dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [raw]
# DATA ANALYSIS:-
# PassengerId: Unique identifier for each passenger.
# Survived   : Indicates whether the passenger survived (1) or not (0).
# Pclass     : Passenger class (1 = 1st class, 2 = 2nd class, 3 = 3rd class).
# Name       : Passenger's name.
# Sex        : Passenger's sex (male or female).
# Age        : Passenger's age in years (may contain missing values).
# SibSp      : Number of siblings/spouses aboard the Titanic with the passenger.
# Parch      : Number of parents/children aboard the Titanic with the passenger.
# TicketFare : Passenger fare paid.
# Cabin      : Cabin number (may contain missing values).
# Embarked   : Port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton).

# %%
titanic = pd.read_csv(r"C:\Users\ACER PC\Dropbox\My PC (LAPTOP-83BUHU5P)\Downloads\titanic.csv",index_col = 'PassengerId')
titanic   ### this for making the column as an index
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
n = titanic.copy()
n
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
t = titanic.copy()
t
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
t.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# ### HANDLING OF MISSING DATA

# %%
n.count()
# Out:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         714
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       204
# Embarked    889
# dtype: int64

# %%
n.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
n.notnull().sum()
# Out:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         714
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       204
# Embarked    889
# dtype: int64

# %%
n.isnull().count()
# Out:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         891
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       891
# Embarked    891
# dtype: int64

# %%
len(n) - n.count()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
n.isnull().sum()/n.shape[0]*100
# Out:
# Survived     0.000000
# Pclass       0.000000
# Name         0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Ticket       0.000000
# Fare         0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
n.shape[0]
# Out:
# 891

# %% [raw]
# ---  ---  --- observation kya hai iss data ko dekh kar
# - Pclass 1
# - Survived Yes
# - they can't be family because family is zero
# - they can't be siblings
# - they can't be friends because of Age gap
# - they can be care taker and person

# %% [markdown]
# ## FILLING THE EMPTY DATASET IN THE COLUMN OF EMBARKMENT

# %%
n[n.Embarked.isnull()]
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 62                  1       1                        Icard, Miss. Amelie
# 830                 1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#                 Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# PassengerId
# 62           female  38.0      0      0  113572  80.0   B28      NaN
# 830          female  62.0      0      0  113572  80.0   B28      NaN

# %%
titanic[titanic.Embarked.isnull()]
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 62                  1       1                        Icard, Miss. Amelie
# 830                 1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#                 Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# PassengerId
# 62           female  38.0      0      0  113572  80.0   B28      NaN
# 830          female  62.0      0      0  113572  80.0   B28      NaN

# %%
list1 = n[n.Embarked.isnull()].index
list1
# Out:
# Index([62, 830], dtype='int64', name='PassengerId')

# %%
for i in list1:
    n['Embarked'].loc[i] = n['Embarked'].replace(np.nan,'S', inplace=True)
n
# Out:
# C:\Users\ACER PC\AppData\Local\Temp\ipykernel_18540\257850964.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   n['Embarked'].loc[i] = n['Embarked'].replace(np.nan,'S', inplace=True)
# C:\Users\ACER PC\AppData\Local\Temp\ipykernel_18540\257850964.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...

# %%
n[(n['Pclass'] == 1)  &  (n['Sex'] == 'female')  & (n['Embarked'] == 'C')].count()
# Out:
# Survived    43
# Pclass      43
# Name        43
# Sex         43
# Age         38
# SibSp       43
# Parch       43
# Ticket      43
# Fare        43
# Cabin       35
# Embarked    43
# dtype: int64

# %%
n[(n['Pclass'] == 1)  &  (n['Sex'] == 'female')  & (n['Embarked'] == 'S')].count()
# Out:
# Survived    49
# Pclass      49
# Name        49
# Sex         49
# Age         45
# SibSp       49
# Parch       49
# Ticket      49
# Fare        49
# Cabin       44
# Embarked    49
# dtype: int64

# %%
n[(n['Pclass'] == 1)  &  (n['Sex'] == 'female')  & (n['Embarked'] == 'Q')].count()
# Out:
# Survived    1
# Pclass      1
# Name        1
# Sex         1
# Age         1
# SibSp       1
# Parch       1
# Ticket      1
# Fare        1
# Cabin       1
# Embarked    1
# dtype: int64

# %%
n1['Embarked'].replace(np.nan, 'S', inplace=True)
n1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 n1['Embarked'].replace(np.nan, 'S', inplace=True)
#       2 n1
#
# NameError: name 'n1' is not defined

# %%
n.Embarked.isnull().replace(np.nan,'S', inplace=True)
n
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
n[n.Embarked.isnull()]
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 830                 1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#                 Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# PassengerId
# 830          female  62.0      0      0  113572  80.0   B28     None

# %%
n
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
n.loc[830,'Embarked'] = 'S'

# %%
n.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      0
# dtype: int64

# %%
n
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### FILLING THE EMPTY DATASET IN THE AGE COLUMN

# %%
n.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      0
# dtype: int64

# %%
n[(n['Pclass'] == 1)  &  (n['Age'].isnull()) ].count()
# Out:
# Survived    30
# Pclass      30
# Name        30
# Sex         30
# Age          0
# SibSp       30
# Parch       30
# Ticket      30
# Fare        30
# Cabin       16
# Embarked    30
# dtype: int64

# %%
n[(n['Pclass'] == 2)  &  (n['Age'].isnull()) ].count()
# Out:
# Survived    11
# Pclass      11
# Name        11
# Sex         11
# Age          0
# SibSp       11
# Parch       11
# Ticket      11
# Fare        11
# Cabin        1
# Embarked    11
# dtype: int64

# %%
n[(n['Pclass'] == 3)  &  (n['Age'].isnull()) ].count()
# Out:
# Survived    136
# Pclass      136
# Name        136
# Sex         136
# Age           0
# SibSp       136
# Parch       136
# Ticket      136
# Fare        136
# Cabin         2
# Embarked    136
# dtype: int64

# %%
n[(n['Pclass'] == 1)  &  (n['Age'].isnull())]
# Out:
#              Survived  Pclass  \
# PassengerId
# 32                  1       1
# 56                  1       1
# 65                  0       1
# 167                 1       1
# 169                 0       1
# 186                 0       1
# 257                 1       1
# 271                 0       1
# 285                 0       1
# 296                 0       1
# 299                 1       1
# 307                 1       1
# 335                 1       1
# 352                 0       1
# 376                 1       1
# 458                 1       1
# 476                 0       1
# 508                 1       1
# 528                 0       1
# 558                 0       1
# 603                 0       1
# 634                 0       1
# 670                 1       1
# 712                 0       1
# 741                 1       1
# 767                 0       1
# 794                 0       1
# 816                 0       1
# 840                 1       1
# ...

# %%
n[n['Pclass'] == 1]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 12                  1       1
# 24                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 24                                Sloper, Mr. William Thompson    male  28.0
# ...                                                        ...     ...   ...
# ...

# %%
sns.displot(x = n.Age,y = n.Pclass,bins = 25,kde = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 sns.displot(x = n.Age,y = n.Pclass,bins = 25,kde = True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\seaborn\distributions.py:2198, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2195     else:
#    2197         _assign_default_kwargs(hist_kws, p.plot_bivariate_histogram, histplot)
# -> 2198         p.plot_bivariate_histogram(**hist_kws)
#    2200 elif kind == "kde":
#    2202     kde_kws = kwargs.copy()
#
# ...

# %%
sns.boxplot(x = n.Pclass,y = n.Age)

# %%
n.Age.max()

# %%
n[n.Age == 80]
# Out:
#              Survived  Pclass                                  Name   Sex  \
# PassengerId
# 631                 1       1  Barkworth, Mr. Algernon Henry Wilson  male
#
#               Age  SibSp  Parch Ticket  Fare Cabin Embarked
# PassengerId
# 631          80.0      0      0  27042  30.0   A23        S

# %% [markdown]
# ### for pclass 1 age distribution

# %% [raw]
# OBSERVATION IN PCLASS == 1
# - THE MAX AGE IS 80
# - MIN AGE IS 0.92
# -  GRPH GENERARLLY LIE BETWEEN  25  TO 50
# - Median is 37.0 of this class

# %%
 a1 = n[n['Pclass'] == 1]

# %%
a1
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 12                  1       1
# 24                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 24                                Sloper, Mr. William Thompson    male  28.0
# ...                                                        ...     ...   ...
# ...

# %%
a1.Age.min()
# Out:
# 0.92

# %%
a1.Age.max()
# Out:
# 80.0

# %%
a1.Age.median()
# Out:
# 37.0

# %%
a1.Age.mean()
# Out:
# 38.233440860215055

# %%
a1.Age.mode()
# Out:
# 0    35.0
# 1    36.0
# Name: Age, dtype: float64

# %%
a1.Age.value_counts()
# Out:
# Age
# 36.00    9
# 35.00    9
# 24.00    7
# 38.00    6
# 30.00    6
# 22.00    5
# 31.00    5
# 47.00    5
# 45.00    5
# 49.00    5
# 40.00    5
# 19.00    5
# 48.00    5
# 58.00    5
# 39.00    5
# 50.00    5
# 27.00    4
# 56.00    4
# 18.00    4
# 33.00    4
# 52.00    4
# 42.00    4
# 54.00    4
# 28.00    4
# 25.00    3
# 16.00    3
# 23.00    3
# 17.00    3
# 60.00    3
# 51.00    3
# 29.00    3
# 21.00    3
# 62.00    3
# 37.00    3
# 44.00    3
# 65.00    2
# 64.00    2
# 61.00    2
# 46.00    2
# 26.00    2
# 71.00    2
# 32.00    2
# 80.00    1
# 15.00    1
# 70.00    1
# 43.00    1
# 53.00    1
# 55.00    1
# 41.00    1
# 34.00    1
# 4.00     1
# 14.00    1
# 45.50    1
# 0.92     1
# 2.00     1
# 63.00    1
# 11.00    1
# Name: count, dtype: int64

# %%
a1.Age.isnull().sum()
# Out:
# 30

# %%
a1[a1.Age.isnull()]
# Out:
#              Survived  Pclass  \
# PassengerId
# 32                  1       1
# 56                  1       1
# 65                  0       1
# 167                 1       1
# 169                 0       1
# 186                 0       1
# 257                 1       1
# 271                 0       1
# 285                 0       1
# 296                 0       1
# 299                 1       1
# 307                 1       1
# 335                 1       1
# 352                 0       1
# 376                 1       1
# 458                 1       1
# 476                 0       1
# 508                 1       1
# 528                 0       1
# 558                 0       1
# 603                 0       1
# 634                 0       1
# 670                 1       1
# 712                 0       1
# 741                 1       1
# 767                 0       1
# 794                 0       1
# 816                 0       1
# 840                 1       1
# ...

# %%
a1.Age.isnull()
# Out:
# PassengerId
# 2      False
# 4      False
# 7      False
# 12     False
# 24     False
#        ...
# 872    False
# 873    False
# 880    False
# 888    False
# 890    False
# Name: Age, Length: 216, dtype: bool

# %%
list1  = a1[a1.Age.isnull()].index
list1
# Out:
# Index([ 32,  56,  65, 167, 169, 186, 257, 271, 285, 296, 299, 307, 335, 352,
#        376, 458, 476, 508, 528, 558, 603, 634, 670, 712, 741, 767, 794, 816,
#        840, 850],
#       dtype='int64', name='PassengerId')

# %%
import random
age = [36,37,38,39,40,41,35,36]
for i in list1:
    ran = random.choice(age)
    a1.loc[i,'Age'] = ran
a1
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 12                  1       1
# 24                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 24                                Sloper, Mr. William Thompson    male  28.0
# ...                                                        ...     ...   ...
# ...

# %%
a1.Age.isnull().sum()
# Out:
# 0

# %%
a1.Age.mean()
# Out:
# 38.1825

# %%
a1.Age.median()
# Out:
# 37.0

# %%
import random
age = [36,37,38,39,40,41,35,36]
for i in list1:
    ran = random.choice(age)
    n.loc[i,'Age'] = ran
n
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
n[(n['Pclass'] == 1)  &  (n['Age'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
n[(n['Pclass'] == 3)  &  (n['Age'].isnull())]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 6                   0       3                          Moran, Mr. James
# 20                  1       3                   Masselmani, Mrs. Fatima
# 27                  0       3                   Emir, Mr. Farred Chehab
# 29                  1       3             O'Dwyer, Miss. Ellen "Nellie"
# 30                  0       3                       Todoroff, Mr. Lalio
# ...               ...     ...                                       ...
# 860                 0       3                          Razi, Mr. Raihed
# 864                 0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869                 0       3               van Melkebeke, Mr. Philemon
# 879                 0       3                        Laleff, Mr. Kristo
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#                 Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# ...

# %% [markdown]
# ### for the Plcass = 2

# %% [raw]
# OBSERVATION IN PCLASS == 1
# - THE MAX AGE IS 80
# - MIN AGE IS 0.92
# -  GRPH GENERARLLY LIE BETWEEN  25  TO 50
# - Median is 37.0 of this class

# %%
 a2 = n[(n['Pclass'] == 2)]

# %%
a2
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 10                  1       2           Nasser, Mrs. Nicholas (Adele Achem)
# 16                  1       2              Hewlett, Mrs. (Mary D Kingcome)
# 18                  1       2                  Williams, Mr. Charles Eugene
# 21                  0       2                          Fynney, Mr. Joseph J
# 22                  1       2                         Beesley, Mr. Lawrence
# ...               ...     ...                                           ...
# 867                 1       2                  Duran y More, Miss. Asuncion
# 875                 1       2         Abelson, Mrs. Samuel (Hannah Wizosky)
# 881                 1       2  Shelley, Mrs. William (Imanita Parrish Hall)
# 884                 0       2                 Banfield, Mr. Frederick James
# 887                 0       2                         Montvila, Rev. Juozas
#
# ...

# %%
a2.Age.isnull().sum()
# Out:
# 11

# %%
a2.Age.value_counts()
# Out:
# Age
# 34.00    10
# 24.00    10
# 28.00     9
# 30.00     8
# 23.00     7
# 25.00     7
# 36.00     7
# 27.00     6
# 29.00     6
# 19.00     6
# 18.00     6
# 31.00     5
# 42.00     5
# 50.00     4
# 54.00     4
# 32.00     4
# 21.00     4
# 40.00     3
# 3.00      3
# 39.00     3
# 35.00     3
# 33.00     3
# 48.00     2
# 4.00      2
# 57.00     2
# 45.00     2
# 52.00     2
# 2.00      2
# 22.00     2
# 26.00     2
# 16.00     2
# 8.00      2
# 44.00     2
# 1.00      2
# 0.83      2
# 32.50     2
# 17.00     2
# 55.00     1
# 47.00     1
# 0.67      1
# 6.00      1
# 66.00     1
# 5.00      1
# 60.00     1
# 70.00     1
# 37.00     1
# 7.00      1
# 62.00     1
# 41.00     1
# 13.00     1
# 36.50     1
# 51.00     1
# 46.00     1
# 38.00     1
# 59.00     1
# 43.00     1
# 14.00     1
# Name: count, dtype: int64

# %%
a2.Age.max()
# Out:
# 70.0

# %%
a2.Age.min()
# Out:
# 0.67

# %%
a2.Age.mean()
# Out:
# 29.87763005780347

# %%
a2.Age.median()
# Out:
# 29.0

# %%
a2[a2.Age.isnull()]
# Out:
#              Survived  Pclass                              Name     Sex  Age  \
# PassengerId
# 18                  1       2      Williams, Mr. Charles Eugene    male  NaN
# 182                 0       2                  Pernot, Mr. Rene    male  NaN
# 278                 0       2       Parkes, Mr. Francis "Frank"    male  NaN
# 304                 1       2               Keane, Miss. Nora A  female  NaN
# 414                 0       2    Cunningham, Mr. Alfred Fleming    male  NaN
# 467                 0       2             Campbell, Mr. William    male  NaN
# 482                 0       2  Frost, Mr. Anthony Wood "Archie"    male  NaN
# 548                 1       2        Padro y Manent, Mr. Julian    male  NaN
# 597                 1       2        Leitch, Miss. Jessie Wills  female  NaN
# 675                 0       2        Watson, Mr. Ennis Hastings    male  NaN
# 733                 0       2              Knight, Mr. Robert J    male  NaN
#
# ...

# %%
list2  = a2[a2.Age.isnull()].index
list2
# Out:
# Index([18, 182, 278, 304, 414, 467, 482, 548, 597, 675, 733], dtype='int64', name='PassengerId')

# %%
age1 = []
for i in range(24,37):
    age1.append(i)
for i in list2:
    ran = random.choice(age)
    a2.loc[i,'Age'] = ran
a2
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 10                  1       2           Nasser, Mrs. Nicholas (Adele Achem)
# 16                  1       2              Hewlett, Mrs. (Mary D Kingcome)
# 18                  1       2                  Williams, Mr. Charles Eugene
# 21                  0       2                          Fynney, Mr. Joseph J
# 22                  1       2                         Beesley, Mr. Lawrence
# ...               ...     ...                                           ...
# 867                 1       2                  Duran y More, Miss. Asuncion
# 875                 1       2         Abelson, Mrs. Samuel (Hannah Wizosky)
# 881                 1       2  Shelley, Mrs. William (Imanita Parrish Hall)
# 884                 0       2                 Banfield, Mr. Frederick James
# 887                 0       2                         Montvila, Rev. Juozas
#
# ...

# %%
a2.Age.isnull().sum()
# Out:
# 0

# %%
a2.Age.mean()
# Out:
# 30.31429347826087

# %%
a2.Age.median()
# Out:
# 30.0

# %%
age1 = []
for i in range(24,37):
    age1.append(i)
for i in list2:
    ran = random.choice(age)
    n.loc[i,'Age'] = ran
n
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
n.Age.isnull().sum()
# Out:
# 136

# %% [markdown]
# ### for pclass 3 dataset

# %%
a3 = n[(n['Pclass'] == 3)]

# %%
a3
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 1                   0       3                   Braund, Mr. Owen Harris
# 3                   1       3                    Heikkinen, Miss. Laina
# 5                   0       3                  Allen, Mr. William Henry
# 6                   0       3                          Moran, Mr. James
# 8                   0       3            Palsson, Master. Gosta Leonard
# ...               ...     ...                                       ...
# 883                 0       3              Dahlberg, Miss. Gerda Ulrika
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# ...

# %%
a3.Age.isnull().sum()
# Out:
# 136

# %%
n["Family"] = n['SibSp'] + n['Parch']
n
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
n.drop(columns = 'integer-of-nod',inplace = True)
n
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 n.drop(columns = 'integer-of-nod',inplace = True)
#       2 n
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
a4 = n[n['Pclass'] == 3]

# %%
a4
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 1                   0       3                   Braund, Mr. Owen Harris
# 3                   1       3                    Heikkinen, Miss. Laina
# 5                   0       3                  Allen, Mr. William Henry
# 6                   0       3                          Moran, Mr. James
# 8                   0       3            Palsson, Master. Gosta Leonard
# ...               ...     ...                                       ...
# 883                 0       3              Dahlberg, Miss. Gerda Ulrika
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# ...

# %%
a4.Family.max()
# Out:
# 10

# %%
a4.Family.min()
# Out:
# 0

# %%
a4[(a4.Age.isnull()) & (a4.Family > 0)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 47                  0       3
# 49                  0       3
# 66                  1       3
# 110                 1       3
# 129                 1       3
# 141                 0       3
# 160                 0       3
# 177                 0       3
# 181                 0       3
# 187                 1       3
# 202                 0       3
# 215                 0       3
# 230                 0       3
# 241                 0       3
# 242                 1       3
# 302                 1       3
# 325                 0       3
# 331                 1       3
# 348                 1       3
# 365                 0       3
# 410                 0       3
# 432                 1       3
# 452                 0       3
# 486                 0       3
# 491                 0       3
# 534                 1       3
# 579                 0       3
# 594                 0       3
# 613                 1       3
# ...

# %%
a4[(a4.Age.isnull()) & (a4.Family > 0)].count()
# Out:
# Survived    37
# Pclass      37
# Name        37
# Sex         37
# Age          0
# SibSp       37
# Parch       37
# Ticket      37
# Fare        37
# Cabin        1
# Embarked    37
# Family      37
# dtype: int64

# %%
a4[(a4.Age.isnull()) & (a4.Family > 0)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 47                  0       3
# 49                  0       3
# 66                  1       3
# 110                 1       3
# 129                 1       3
# 141                 0       3
# 160                 0       3
# 177                 0       3
# 181                 0       3
# 187                 1       3
# 202                 0       3
# 215                 0       3
# 230                 0       3
# 241                 0       3
# 242                 1       3
# 302                 1       3
# 325                 0       3
# 331                 1       3
# 348                 1       3
# 365                 0       3
# 410                 0       3
# 432                 1       3
# 452                 0       3
# 486                 0       3
# 491                 0       3
# 534                 1       3
# 579                 0       3
# 594                 0       3
# 613                 1       3
# ...

# %%
a4[(a4.Age.isnull()) & (a4.Family == 0)]
# Out:
#              Survived  Pclass                           Name     Sex  Age  \
# PassengerId
# 6                   0       3               Moran, Mr. James    male  NaN
# 20                  1       3        Masselmani, Mrs. Fatima  female  NaN
# 27                  0       3        Emir, Mr. Farred Chehab    male  NaN
# 29                  1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
# 30                  0       3            Todoroff, Mr. Lalio    male  NaN
# ...               ...     ...                            ...     ...  ...
# 833                 0       3                 Saad, Mr. Amin    male  NaN
# 838                 0       3            Sirota, Mr. Maurice    male  NaN
# 860                 0       3               Razi, Mr. Raihed    male  NaN
# 869                 0       3    van Melkebeke, Mr. Philemon    male  NaN
# 879                 0       3             Laleff, Mr. Kristo    male  NaN
#
#              SibSp  Parch  Ticket    Fare Cabin Embarked  Family
# ...

# %%
a4[(a4.Age.notnull()) & (a4.Family > 0)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 8                   0       3
# 9                   1       3
# 11                  1       3
# 14                  0       3
# ...               ...     ...
# 856                 1       3
# 859                 1       3
# 861                 0       3
# 870                 1       3
# 886                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 14                                 Andersson, Mr. Anders Johan    male  39.0
# ...                                                        ...     ...   ...
# ...

# %%
a4[(a4.Age.notnull()) & (a4.Family > 0)].dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# Family        int64
# dtype: object

# %%
a4[(a4.Age.notnull()) & (a4.Family > 0)].Age
# Out:
# PassengerId
# 1      22.0
# 8       2.0
# 9      27.0
# 11      4.0
# 14     39.0
#        ...
# 856    18.0
# 859    24.0
# 861    41.0
# 870     4.0
# 886    39.0
# Name: Age, Length: 130, dtype: float64

# %%
a4[(a4.Age.notnull()) & (a4.Family > 0)].Age.mean()
# Out:
# 19.784

# %%
a4[(a4.Age.notnull()) & (a4.Family == 0)].Age.mean()
# Out:
# 28.235555555555557

# %%
a4[(a4.Age.notnull()) & (a4.Family > 0)].Age.median()
# Out:
# 18.0

# %%
a4[(a4.Age.notnull()) & (a4.Family == 0)].Age.median()
# Out:
# 26.0

# %% [markdown]
# ### for age column is null and there is no family in it

# %%
a4
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 1                   0       3                   Braund, Mr. Owen Harris
# 3                   1       3                    Heikkinen, Miss. Laina
# 5                   0       3                  Allen, Mr. William Henry
# 6                   0       3                          Moran, Mr. James
# 8                   0       3            Palsson, Master. Gosta Leonard
# ...               ...     ...                                       ...
# 883                 0       3              Dahlberg, Miss. Gerda Ulrika
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# ...

# %%
af1 = a4[a4.Family == 0]

# %%
af1
# Out:
#              Survived  Pclass                                  Name     Sex  \
# PassengerId
# 3                   1       3                Heikkinen, Miss. Laina  female
# 5                   0       3              Allen, Mr. William Henry    male
# 6                   0       3                      Moran, Mr. James    male
# 13                  0       3        Saundercock, Mr. William Henry    male
# 15                  0       3  Vestrom, Miss. Hulda Amanda Adolfina  female
# ...               ...     ...                                   ...     ...
# 879                 0       3                    Laleff, Mr. Kristo    male
# 882                 0       3                    Markun, Mr. Johann    male
# 883                 0       3          Dahlberg, Miss. Gerda Ulrika  female
# 885                 0       3                Sutehall, Mr. Henry Jr    male
# 891                 0       3                   Dooley, Mr. Patrick    male
#
# ...

# %%
af1.Age.max()
# Out:
# 74.0

# %%
af1.Age.min()
# Out:
# 5.0

# %%
af1.Age.mean()
# Out:
# 28.235555555555557

# %%
af1.Age.median()
# Out:
# 26.0

# %%
af1.Age.value_counts()
# Out:
# Age
# 22.0    19
# 21.0    15
# 19.0    13
# 20.0    12
# 32.0    10
# 26.0     9
# 28.0     9
# 30.0     9
# 25.0     9
# 18.0     9
# 24.0     8
# 29.0     7
# 16.0     7
# 33.0     6
# 27.0     5
# 35.0     5
# 23.0     5
# 17.0     5
# 31.0     5
# 34.0     3
# 42.0     3
# 36.0     3
# 39.0     3
# 45.0     3
# 38.0     3
# 44.0     3
# 51.0     3
# 15.0     2
# 43.0     2
# 28.5     2
# 30.5     2
# 40.0     2
# 47.0     2
# 11.0     1
# 24.5     1
# 41.0     1
# 48.0     1
# 5.0      1
# 13.0     1
# 34.5     1
# 49.0     1
# 61.0     1
# 40.5     1
# 37.0     1
# 63.0     1
# 50.0     1
# 23.5     1
# 65.0     1
# 20.5     1
# 45.5     1
# 55.5     1
# 70.5     1
# 14.0     1
# 59.0     1
# 74.0     1
# Name: count, dtype: int64

# %%
list3  = af1[af1.Age.isnull()].index
list3
# Out:
# Index([  6,  20,  27,  29,  30,  33,  37,  43,  46,  48,  77,  78,  83,  88,
#         96, 102, 108, 122, 127, 155, 159, 197, 199, 224, 236, 251, 261, 265,
#        275, 301, 305, 336, 355, 359, 360, 368, 369, 385, 389, 411, 412, 416,
#        421, 426, 429, 445, 455, 460, 465, 469, 471, 496, 498, 503, 512, 518,
#        523, 525, 532, 539, 553, 561, 564, 565, 569, 574, 585, 590, 599, 602,
#        612, 614, 630, 644, 649, 651, 654, 657, 668, 681, 693, 698, 719, 728,
#        739, 740, 761, 774, 777, 779, 791, 826, 827, 829, 833, 838, 860, 869,
#        879],
#       dtype='int64', name='PassengerId')

# %%
age3 = []
for i in range(22,33):
    age3.append(i)
for i in list3:
    ran = random.choice(age)
    af1.loc[i,'Age'] = ran
af1
# Out:
#              Survived  Pclass                                  Name     Sex  \
# PassengerId
# 3                   1       3                Heikkinen, Miss. Laina  female
# 5                   0       3              Allen, Mr. William Henry    male
# 6                   0       3                      Moran, Mr. James    male
# 13                  0       3        Saundercock, Mr. William Henry    male
# 15                  0       3  Vestrom, Miss. Hulda Amanda Adolfina  female
# ...               ...     ...                                   ...     ...
# 879                 0       3                    Laleff, Mr. Kristo    male
# 882                 0       3                    Markun, Mr. Johann    male
# 883                 0       3          Dahlberg, Miss. Gerda Ulrika  female
# 885                 0       3                Sutehall, Mr. Henry Jr    male
# 891                 0       3                   Dooley, Mr. Patrick    male
#
# ...

# %%
af1.Age.isnull().sum()
# Out:
# 0

# %%
af1.Age.mean()
# Out:
# 31.117283950617285

# %%
af1.Age.median()
# Out:
# 32.0

# %% [markdown]
# ### Data for family is greater than 0 and less than 4

# %%
a4
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 1                   0       3                   Braund, Mr. Owen Harris
# 3                   1       3                    Heikkinen, Miss. Laina
# 5                   0       3                  Allen, Mr. William Henry
# 6                   0       3                          Moran, Mr. James
# 8                   0       3            Palsson, Master. Gosta Leonard
# ...               ...     ...                                       ...
# 883                 0       3              Dahlberg, Miss. Gerda Ulrika
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# ...

# %%
af2 = a4[(a4.Family > 0) & (a4.Family <= 4)]
af2
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 8                   0       3
# 9                   1       3
# 11                  1       3
# 19                  0       3
# ...               ...     ...
# 856                 1       3
# 859                 1       3
# 861                 0       3
# 870                 1       3
# 889                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# ...                                                        ...     ...   ...
# ...

# %%
af2.Age.mean()
# Out:
# 21.525473684210528

# %%
af2.Age.median()
# Out:
# 24.0

# %%
af2.Age.isnull().sum()
# Out:
# 30

# %%
af2.Age.value_counts()
# Out:
# Age
# 18.00    7
# 24.00    5
# 26.00    5
# 4.00     4
# 9.00     4
# 25.00    4
# 29.00    4
# 2.00     3
# 27.00    3
# 28.00    3
# 1.00     3
# 16.00    3
# 36.00    3
# 20.00    3
# 21.00    2
# 0.75     2
# 32.00    2
# 41.00    2
# 3.00     2
# 30.00    2
# 15.00    2
# 17.00    2
# 33.00    2
# 40.00    2
# 31.00    2
# 10.00    1
# 5.00     1
# 45.00    1
# 34.00    1
# 48.00    1
# 6.00     1
# 22.00    1
# 19.00    1
# 35.00    1
# 42.00    1
# 44.00    1
# 40.50    1
# 47.00    1
# 12.00    1
# 14.50    1
# 37.00    1
# 14.00    1
# 8.00     1
# 0.42     1
# Name: count, dtype: int64

# %%
list4  = af2[af2.Age.isnull()].index
list4
# Out:
# Index([ 47,  49,  66, 110, 129, 141, 177, 187, 215, 230, 241, 242, 302, 331,
#        348, 365, 410, 432, 452, 486, 491, 534, 579, 594, 613, 640, 710, 769,
#        784, 889],
#       dtype='int64', name='PassengerId')

# %%
age4 = []
for i in range(18,27):
    age4.append(i)
for i in list4:
    ran = random.choice(age)
    af2.loc[i,'Age'] = ran
af2
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 8                   0       3
# 9                   1       3
# 11                  1       3
# 19                  0       3
# ...               ...     ...
# 856                 1       3
# 859                 1       3
# 861                 0       3
# 870                 1       3
# 889                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# ...                                                        ...     ...   ...
# ...

# %%
af2.Age.isnull().sum()
# Out:
# 0

# %%
af2.Age.mean()
# Out:
# 25.49536

# %%
af2.Age.median()
# Out:
# 27.0

# %% [markdown]
# ### changing in the original dataset

# %%
age4 = []
for i in range(18,27):
    age4.append(i)
for i in list4:
    ran = random.choice(age)
    n.loc[i,'Age'] = ran
n
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
age3 = []
for i in range(22,33):
    age3.append(i)
for i in list3:
    ran = random.choice(age)
    n.loc[i,'Age'] = ran
n
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### for family greater then 4

# %%
af3 = a4[(a4.Family > 4)]
af3
# Out:
#              Survived  Pclass  \
# PassengerId
# 14                  0       3
# 17                  0       3
# 26                  1       3
# 51                  0       3
# 60                  0       3
# 64                  0       3
# 69                  1       3
# 72                  0       3
# 120                 0       3
# 160                 0       3
# 165                 0       3
# 168                 0       3
# 172                 0       3
# 181                 0       3
# 183                 0       3
# 202                 0       3
# 234                 1       3
# 262                 1       3
# 267                 0       3
# 279                 0       3
# 325                 0       3
# 361                 0       3
# 387                 0       3
# 481                 0       3
# 542                 0       3
# 543                 0       3
# 611                 0       3
# 635                 0       3
# 639                 0       3
# ...

# %%
af3.Age.min()
# Out:
# 1.0

# %%
af3.Age.max()
# Out:
# 45.0

# %%
af3.Age.mean()
# Out:
# 15.057142857142857

# %%
af3.Age.median()
# Out:
# 9.0

# %%
af3.Age.value_counts()
# Out:
# Age
# 9.0     4
# 2.0     4
# 4.0     3
# 39.0    3
# 11.0    2
# 7.0     2
# 16.0    2
# 1.0     2
# 14.0    2
# 17.0    1
# 45.0    1
# 38.0    1
# 5.0     1
# 3.0     1
# 40.0    1
# 41.0    1
# 43.0    1
# 8.0     1
# 6.0     1
# 10.0    1
# Name: count, dtype: int64

# %%
list4  = af3[af3.Age.isnull()].index
list4
# Out:
# Index([160, 181, 202, 325, 793, 847, 864], dtype='int64', name='PassengerId')

# %%
age4 = []
for i in range(2,10):
    age4.append(i)
for i in list4:
    ran = random.choice(age)
    af3.loc[i,'Age'] = ran
af3
# Out:
#              Survived  Pclass  \
# PassengerId
# 14                  0       3
# 17                  0       3
# 26                  1       3
# 51                  0       3
# 60                  0       3
# 64                  0       3
# 69                  1       3
# 72                  0       3
# 120                 0       3
# 160                 0       3
# 165                 0       3
# 168                 0       3
# 172                 0       3
# 181                 0       3
# 183                 0       3
# 202                 0       3
# 234                 1       3
# 262                 1       3
# 267                 0       3
# 279                 0       3
# 325                 0       3
# 361                 0       3
# 387                 0       3
# 481                 0       3
# 542                 0       3
# 543                 0       3
# 611                 0       3
# 635                 0       3
# 639                 0       3
# ...

# %%
af3.Age.isnull().sum()
# Out:
# 0

# %%
age4 = []
for i in range(2,10):
    age4.append(i)
for i in list4:
    ran = random.choice(age)
    n.loc[i,'Age'] = ran
n
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
n.Age.isnull().sum()
# Out:
# 0

# %%
n
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
af3.Age.mean()
# Out:
# 18.61904761904762

# %%
af3.Age.median()
# Out:
# 11.0

# %%
n.Age.median()
# Out:
# 32.0

# %%
n.Age.mean()
# Out:
# 31.287508417508416

# %%
titanic.Age.mean()
# Out:
# 29.69911764705882

# %%
titanic.Age.median()
# Out:
# 28.0

# %%
n.Age.isnull().sum()
# Out:
# 0

# %%
def agecat(data):
    if   0.42<=data<21: return 'Children'
    elif 21<=data<40: return 'Younger'
    elif 40<=data<61: return 'Elder'
    elif 61<=data<=80: return 'Senior-Citizens'
    else               :  return np.nan
n['AgeGroups'] = n.Age.apply(agecat)
n
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
n.AgeGroups.isnull().sum()
# Out:
# 0

# %%
a = titanic.copy()
a
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ## 19-06-2024

# %% [markdown]
# ### Fillna is used to put all of the missing value

# %%
a.fillna(100)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex    Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 3                                       Heikkinen, Miss. Laina  female   26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 5                                     Allen, Mr. William Henry    male   35.0
# ...                                                        ...     ...    ...
# ...

# %%
a1= titanic.copy()
a1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
a1[a1. == 'Nan']
# Out:
#              Survived  Pclass Name  Sex  Age  SibSp  Parch Ticket  Fare Cabin  \
# PassengerId
# 1                 NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN   NaN
# 2                 NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN   NaN
# 3                 NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN   NaN
# 4                 NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN   NaN
# 5                 NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN   NaN
# ...               ...     ...  ...  ...  ...    ...    ...    ...   ...   ...
# 887               NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN   NaN
# 888               NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN   NaN
# 889               NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN   NaN
# 890               NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN   NaN
# 891               NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN   NaN
#
# ...

# %%
a1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
a1.isnull().any()
# Out:
# Survived    False
# Pclass      False
# Name        False
# Sex         False
# Age          True
# SibSp       False
# Parch       False
# Ticket      False
# Fare        False
# Cabin        True
# Embarked     True
# dtype: bool

# %%
df = pd.DataFrame({ 'A':[10,20,30,np.nan],
                'B':[30,20,np.nan,40],
                'C' : [np.nan,20,30,50]})

# %%
df
# Out:
#       A     B     C
# 0  10.0  30.0   NaN
# 1  20.0  20.0  20.0
# 2  30.0   NaN  30.0
# 3   NaN  40.0  50.0

# %%
df1 = df.copy()
df1
# Out:
#       A     B     C
# 0  10.0  30.0   NaN
# 1  20.0  20.0  20.0
# 2  30.0   NaN  30.0
# 3   NaN  40.0  50.0

# %%
df.mean()
# Out:
# A    20.000000
# B    30.000000
# C    33.333333
# dtype: float64

# %%
df.fillna(round(df.mean(),2))
# Out:
#       A     B      C
# 0  10.0  30.0  33.33
# 1  20.0  20.0  20.00
# 2  30.0  30.0  30.00
# 3  20.0  40.0  50.00

# %%
df1.fillna(method = 'ffill')
# Out:
# C:\Users\ACER PC\AppData\Local\Temp\ipykernel_18540\952515349.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method = 'ffill')
#       A     B     C
# 0  10.0  30.0   NaN
# 1  20.0  20.0  20.0
# 2  30.0  20.0  30.0
# 3  30.0  40.0  50.0

# %%
df1.fillna(method = 'bfill')
# Out:
# C:\Users\ACER PC\AppData\Local\Temp\ipykernel_18540\1343493749.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method = 'bfill')
#       A     B     C
# 0  10.0  30.0  20.0
# 1  20.0  20.0  20.0
# 2  30.0  40.0  30.0
# 3   NaN  40.0  50.0

# %%
df
# Out:
#       A     B     C
# 0  10.0  30.0   NaN
# 1  20.0  20.0  20.0
# 2  30.0   NaN  30.0
# 3   NaN  40.0  50.0

# %%
df2 = df.copy()
df2
# Out:
#       A     B     C
# 0  10.0  30.0   NaN
# 1  20.0  20.0  20.0
# 2  30.0   NaN  30.0
# 3   NaN  40.0  50.0

# %%
df2.dropna() ## bydeault axis = 0
# Out:
#       A     B     C
# 1  20.0  20.0  20.0

# %%
df2.dropna(axis =1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df
# Out:
#       A     B     C
# 0  10.0  30.0   NaN
# 1  20.0  20.0  20.0
# 2  30.0   NaN  30.0
# 3   NaN  40.0  50.0

# %%
a1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
a11 = a1[5:9].drop(columns = ['Parch','SibSp'])

# %%
a11
# Out:
#              Survived  Pclass  \
# PassengerId
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
#
#              Ticket     Fare Cabin Embarked
# PassengerId
# 6            330877   8.4583   NaN        Q
# 7             17463  51.8625   E46        S
# 8            349909  21.0750   NaN        S
# 9            347742  11.1333   NaN        S

# %%
a12 = a1[50:52] ### by deault works on iloc

# %%
a12
# Out:
#              Survived  Pclass                          Name   Sex   Age  \
# PassengerId
# 51                  0       3    Panula, Master. Juha Niilo  male   7.0
# 52                  0       3  Nosworthy, Mr. Richard Cater  male  21.0
#
#              SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# 51               4      1     3101295  39.6875   NaN        S
# 52               0      0  A/4. 39886   7.8000   NaN        S

# %%
a13 = pd.concat([a11,a12])

# %%
a13
# Out:
#              Survived  Pclass  \
# PassengerId
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 51                  0       3
# 52                  0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 51                                  Panula, Master. Juha Niilo    male   7.0
# 52                                Nosworthy, Mr. Richard Cater    male  21.0
#
#                  Ticket     Fare Cabin Embarked  SibSp  Parch
# PassengerId
# 6                330877   8.4583   NaN        Q    NaN    NaN
# ...

# %% [markdown]
# ### EXCEL SHEET READ AND CONCATINATE

# %%
e1 = pd.read_excel("E:\Book1.xlsx",index_col = 'NAME')
e1
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\ACER PC\AppData\Local\Temp\ipykernel_18540\739545578.py:1: SyntaxWarning: invalid escape sequence '\B'
#   e1 = pd.read_excel("E:\Book1.xlsx",index_col = 'NAME')
#        PHYSICS  CHEMISTRY
# NAME
# DHRUV       90         91
# AAYAN       87         86
# YASH        85         89

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/251.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/251.4 kB ? eta -:--:--
#    --------- ----------------------------- 61.4/251.4 kB 656.4 kB/s eta 0:00:01
#    -------------------------- ------------- 163.8/251.4 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 251.4/251.4 kB 1.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
e2 = pd.read_excel("E:\Book2.xlsx",index_col = 'NAME')
e2
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\ACER PC\AppData\Local\Temp\ipykernel_18540\1920894473.py:1: SyntaxWarning: invalid escape sequence '\B'
#   e2 = pd.read_excel("E:\Book2.xlsx",index_col = 'NAME')
#        ENGLISH  MATHS
# NAME
# DHRUV       79     77
# AAYAN       87     86
# YASH        85     89

# %%
e3 = pd.concat([e1,e2],axis = 1)

# %%
e3
# Out:
#        PHYSICS  CHEMISTRY  ENGLISH  MATHS
# NAME
# DHRUV       90         91       79     77
# AAYAN       87         86       87     86
# YASH        85         89       85     89
